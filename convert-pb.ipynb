# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow import keras
import tensorflow as tf

# %%
pb_model_dir = "/content/drive/MyDrive/tugas-akhir-dhifaf/new-model-ex4-best-model-47466/best_model"
h5_model = "/content/drive/MyDrive/tugas-akhir/new-model-ex4-best-model-47466/my_model.h5"

# %%
# Loading the Tensorflow Saved Model (PB)
model = tf.keras.models.load_model(pb_model_dir)

# %%
model.summary()
# Out:
# Model: "model_1_ex2_fix"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling_4 (Rescaling)        (None, 256, 256, 3)  0           ['input_5[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 32  896         ['rescaling_4[0][0]']
#                                 )
#
#  max_pooling2d_24 (MaxPooling2D  (None, 64, 64, 32)  0           ['conv2d_24[0][0]']
#  )
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 32)  128         ['max_pooling2d_24[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   18496       ['activation_48[0][0]']
#
# ...

# %%
# Saving the Model in H5 Format
tf.keras.models.save_model(model, h5_model)

# %%
# Loading the H5 Saved Model
loaded_model_from_h5 = tf.keras.models.load_model(h5_model)
print(loaded_model_from_h5.summary())
# Out:
# Model: "model_1_ex2_fix"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling_4 (Rescaling)        (None, 256, 256, 3)  0           ['input_5[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 32  896         ['rescaling_4[0][0]']
#                                 )
#
#  max_pooling2d_24 (MaxPooling2D  (None, 64, 64, 32)  0           ['conv2d_24[0][0]']
#  )
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 32)  128         ['max_pooling2d_24[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   18496       ['activation_48[0][0]']
#
# ...
